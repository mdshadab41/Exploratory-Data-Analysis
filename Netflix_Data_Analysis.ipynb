# %% [markdown]
# **Importing Libraries**

# %%
# Code to read csv file into colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Get the file
downloaded = drive.CreateFile({'id':'1lujUGfSb-iMiFaobvi0mfVDjdjm4jyup'}) # replace the id with id of file you want to access
downloaded.GetContentFile('netflix_titles.csv')

# %%
import numpy as np # Linear Algebra
import pandas as pd # Data Processing
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading the Dataset**

# %%
netflix = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# First 10 values

# %%
netflix.head(10)
# Out:
#     show_id  ...                                        description
# 0  81145628  ...  Before planning an awesome wedding for his gra...
# 1  80117401  ...  Jandino Asporaat riffs on the challenges of ra...
# 2  70234439  ...  With the help of three human allies, the Autob...
# 3  80058654  ...  When a prison ship crash unleashes hundreds of...
# 4  80125979  ...  When nerdy high schooler Dani finally attracts...
# 5  80163890  ...  A young journalist is forced into a life of cr...
# 6  70304989  ...  In a dystopian future, an insurance adjuster f...
# 7  80164077  ...  Fabrizio Copano takes audience participation t...
# 8  80117902  ...  As California's 2016 fire season rages, brave ...
# 9  70304990  ...  A struggling couple can't believe their luck w...
#
# [10 rows x 12 columns]

# %% [markdown]
# Shape of the dataset

# %%
netflix.shape
# Out:
# (6234, 12)

# %% [markdown]
# Print the name of the columns

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# Check for Null values

# %%
netflix.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# **Check unique values**

# %%
netflix.nunique()
# Out:
# show_id         6234
# type               2
# title           6172
# director        3301
# cast            5469
# country          554
# date_added      1524
# release_year      72
# rating            14
# duration         201
# listed_in        461
# description     6226
# dtype: int64

# %% [markdown]
# **Check for duplicate values**

# %%
netflix.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Make a copy of the dataset**

# %%
df = netflix.copy()

# %%
df.shape
# Out:
# (6234, 12)

# %% [markdown]
# **Drop null values**

# %%
df = df.dropna()
df.shape
# Out:
# (3774, 12)

# %% [markdown]
# **Print first 10 values**

# %%
df.head(10)
# Out:
#      show_id  ...                                        description
# 0   81145628  ...  Before planning an awesome wedding for his gra...
# 4   80125979  ...  When nerdy high schooler Dani finally attracts...
# 6   70304989  ...  In a dystopian future, an insurance adjuster f...
# 7   80164077  ...  Fabrizio Copano takes audience participation t...
# 9   70304990  ...  A struggling couple can't believe their luck w...
# 11  70299204  ...  When beer magnate Alfred "Freddy" Heineken is ...
# 19  80057969  ...  A man in an unsatisfying marriage recalls the ...
# 20  80060297  ...  A filmmaker working on a documentary about lov...
# 21  80046728  ...  A brain-addled war vet, a failing band manager...
# 23  70304988  ...  In 1899, a young doctor arrives at an asylum f...
#
# [10 rows x 12 columns]

# %% [markdown]
# **Convert Date Time format**

# %%
df["date_added"] = pd.to_datetime(df["date_added"])
df["day_added"] = df['date_added'].dt.day
df["year_added"] = df['date_added'].dt.year
df["month_added"] = df['date_added'].dt.month
df["year_added"].astype(int);
df["day_added"].astype(int);

# %%
df.head(10)
# Out:
#      show_id   type  ... year_added month_added
# 0   81145628  Movie  ...       2019           9
# 4   80125979  Movie  ...       2017           9
# 6   70304989  Movie  ...       2017           9
# 7   80164077  Movie  ...       2017           9
# 9   70304990  Movie  ...       2017           9
# 11  70299204  Movie  ...       2017           9
# 19  80057969  Movie  ...       2017           9
# 20  80060297  Movie  ...       2017           9
# 21  80046728  Movie  ...       2017           9
# 23  70304988  Movie  ...       2017           9
#
# [10 rows x 15 columns]

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# **Type: Movie and TV Shows**

# %%
sns.countplot(netflix['type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Type')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Type')

# %% [markdown]
# **Rating of shows and movies**

# %%
sns.countplot(netflix['rating'])
sns.countplot(netflix['rating']).set_xticklabels(sns.countplot(netflix['rating']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Rating')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Rating')

# %% [markdown]
# **Relation between Type and Rating**

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='rating', hue='type', data=netflix)
plt.title('Realtionship between Type and Rating')
plt.show()

# %% [markdown]
# **Pie-chart for the Type: Movie and TV Shows**

# %%
labels = ['Movie', 'TV show']
size = netflix['type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0,1,2))
explode = [0,0.1]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# **Pie-chart for Rating**

# %%
netflix['rating'].value_counts().plot.pie(autopct='%.1f%%', shadow=True, figsize=(12,9))
plt.show()

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud

# %% [markdown]
# Country

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                      background_color = 'white',
                      width=1920,
                      height=1080
                     ).generate(" ".join(df.country))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# **Cast in the Shows**

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.cast))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# **Directors**

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.director))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
